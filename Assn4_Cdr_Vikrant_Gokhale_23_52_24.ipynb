# %% [markdown]
# <a href="https://colab.research.google.com/github/gokhalevikrant/23-52-24/blob/main/Assn4_Cdr_Vikrant_Gokhale_23_52_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1.    Read the housingdata.csv file in a pandas DataFrame & Display first 6 rows of data

# %%
hdf = pd.read_csv('/content/drive/MyDrive/PhD/housingdata.csv')

# %%
hdf.head(6)
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5    --
# 2  100003000.0           AP    2541654          NaN        1   850
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 5  100006000.0           TN   65465466          NaN        1   800

# %% [markdown]
# 2.     Display the column names and row index in separate cells.

# %%
print(list(hdf.columns))
# Out:
# ['PID', 'STATE', 'PRICE', 'NUM_BEDROOMS', 'NUM_BATH', 'SQ_FT']

# %%
print(list(hdf.index))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# 3.   a) How many numbers of “STATE” exist in the dataset. Hint: use shape
# b) How many unique states exist in the dataset

# %%
hdf.shape
# Out:
# (9, 6)

# %%
hdf['STATE'].shape[0]
# Out:
# 9

# %%
hdf['STATE'].nunique()
# Out:
# 6

# %% [markdown]
# 4.   Retrieve the list of all NaN/Null/Empty cells in the form of Boolean list

# %%
hdf.isna()
# Out:
#      PID  STATE  PRICE  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  False  False  False         False     False  False
# 1  False  False  False         False     False  False
# 2  False  False  False          True     False  False
# 3  False  False  False         False      True  False
# 4   True  False  False         False     False  False
# 5  False  False  False          True     False  False
# 6  False  False  False         False     False  False
# 7  False  False  False         False     False   True
# 8  False  False  False         False     False  False

# %%
hdf.columns[hdf.isna().any()].tolist()
# Out:
# ['PID', 'NUM_BEDROOMS', 'NUM_BATH', 'SQ_FT']

# %% [markdown]
# 5.    Drop all rows with N/A,NA,na values in Num_Bedrooms

# %%
hdf.dropna(subset=['NUM_BEDROOMS'])
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5    --
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 6  100007000.0        ASSAM    3222321            2   HURLEY   950
# 7  100008000.0           HP      23131            1        1   NaN
# 8  100009000.0           HP      21212           na        2  1800

# %%
hdf.loc[[8],['NUM_BEDROOMS']]=np.nan

# %%
hdf = hdf.dropna(subset=['NUM_BEDROOMS'])
hdf
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5    --
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 6  100007000.0        ASSAM    3222321            2   HURLEY   950
# 7  100008000.0           HP      23131            1        1   NaN

# %% [markdown]
# 6     Replace the NaN and String entries in Num_Bath with previous entry

# %%
hdf['NUM_BATH'] = pd.to_numeric(hdf['NUM_BATH'], errors='coerce')

# %%
hdf['NUM_BATH'] = hdf['NUM_BATH'].fillna(method='ffill')

# %%
hdf
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS  NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3       1.0  1000
# 1  100002000.0  MAHARASHTRA      21325            3       1.5    --
# 3  100004000.0           TN     321321            1       1.5   700
# 4          NaN           TN  589465645            3       2.0  1600
# 6  100007000.0        ASSAM    3222321            2       2.0   950
# 7  100008000.0           HP      23131            1       1.0   NaN

# %% [markdown]
# 7.    Replace the empty values in “SQ_FT” with the mean of the all entries.

# %%
hdf['SQ_FT'] = pd.to_numeric(hdf['SQ_FT'], errors='coerce')
hdf['SQ_FT'] = hdf['SQ_FT'].fillna(hdf['SQ_FT'].mean())
hdf
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS  NUM_BATH   SQ_FT
# 0  100001000.0           MP     321654            3       1.0  1000.0
# 1  100002000.0  MAHARASHTRA      21325            3       1.5  1062.5
# 3  100004000.0           TN     321321            1       1.5   700.0
# 4          NaN           TN  589465645            3       2.0  1600.0
# 6  100007000.0        ASSAM    3222321            2       2.0   950.0
# 7  100008000.0           HP      23131            1       1.0  1062.5

# %% [markdown]
# 8. Calculate the sum of SQ_FT for all entries in the dataset

# %%
sum_sq_ft = hdf['SQ_FT'].sum()
print(sum_sq_ft)
# Out:
# 6375.0

# %% [markdown]
# 9. Add a new column "NUM_STORE" with all values as 1 for all rows

# %%
hdf['NUM_STORE'] = 1
hdf
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS  NUM_BATH   SQ_FT  \
# 0  100001000.0           MP     321654            3       1.0  1000.0
# 1  100002000.0  MAHARASHTRA      21325            3       1.5  1062.5
# 3  100004000.0           TN     321321            1       1.5   700.0
# 4          NaN           TN  589465645            3       2.0  1600.0
# 6  100007000.0        ASSAM    3222321            2       2.0   950.0
# 7  100008000.0           HP      23131            1       1.0  1062.5
#
#    NUM_STORE
# 0          1
# 1          1
# 3          1
# 4          1
# 6          1
# 7          1

# %% [markdown]
# 10. Create a DataFrame containing all entries of the TN state only

# %%
hdf_TN = hdf[hdf['STATE']=='TN']
hdf_TN
# Out:
#            PID STATE      PRICE NUM_BEDROOMS  NUM_BATH   SQ_FT  NUM_STORE
# 3  100004000.0    TN     321321            1       1.5   700.0          1
# 4          NaN    TN  589465645            3       2.0  1600.0          1

# %% [markdown]
# 11. Create a DataFrame having SQ_FT area greater than 1000 and display the DataFrame

# %%
hdf_area_ths = hdf[hdf['SQ_FT'] > 1000]
hdf_area_ths
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS  NUM_BATH   SQ_FT  \
# 1  100002000.0  MAHARASHTRA      21325            3       1.5  1062.5
# 4          NaN           TN  589465645            3       2.0  1600.0
# 7  100008000.0           HP      23131            1       1.0  1062.5
#
#    NUM_STORE
# 1          1
# 4          1
# 7          1

# %% [markdown]
# 12. Create a DataFrame having only the first three columns and the first three rows

# %%
new_hdf = hdf.iloc[:3,:3]
new_hdf
# Out:
#            PID        STATE   PRICE
# 0  100001000.0           MP  321654
# 1  100002000.0  MAHARASHTRA   21325
# 3  100004000.0           TN  321321

# %% [markdown]
# 13. Display the state having the highest average price per square foot of housing area

# %%
hdf['PRICE_PER_SQ_FT'] = hdf['PRICE']/hdf['SQ_FT']
state_avg_price_per_sq_ft = hdf.groupby('STATE')['PRICE_PER_SQ_FT'].mean().sort_values(ascending=False)
print(state_avg_price_per_sq_ft.index[0])
# Out:
# TN
